# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarisajjad/Code-ai/blob/main/My_model_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --ignore-installed <package_name>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `pip install --ignore-installed <package_name>'

# %%
# !source /content/myenv/bin/activate

# %%
# !pip install <package_name>

# %%
# !cp -r /content/myenv /content/drive/MyDrive/

# %%
# !cp -r /content/drive/MyDrive/myenv /content/
# !source /content/myenv/bin/activate

# %%
# !pip install transformers torch

# %%
# !pip install transformers datasets accelerate

# %%
# !pip install transformers datasets accelerate

# %%
from datasets import load_dataset

# بارگذاری دیتاست CodeSearchNet (زبان پایتون)
dataset = load_dataset('code_search_net', 'python')

# مشاهده ساختار دیتاست
print(dataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 412178
#     })
#     test: Dataset({
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# بارگذاری توکن‌آیزر و مدل
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-mono")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-mono")
# Out:
# Some weights of the model checkpoint at Salesforce/codegen-350M-mono were not used when initializing CodeGenForCausalLM: ['transformer.h.0.attn.causal_mask', 'transformer.h.1.attn.causal_mask', 'transformer.h.10.attn.causal_mask', 'transformer.h.11.attn.causal_mask', 'transformer.h.12.attn.causal_mask', 'transformer.h.13.attn.causal_mask', 'transformer.h.14.attn.causal_mask', 'transformer.h.15.attn.causal_mask', 'transformer.h.16.attn.causal_mask', 'transformer.h.17.attn.causal_mask', 'transformer.h.18.attn.causal_mask', 'transformer.h.19.attn.causal_mask', 'transformer.h.2.attn.causal_mask', 'transformer.h.3.attn.causal_mask', 'transformer.h.4.attn.causal_mask', 'transformer.h.5.attn.causal_mask', 'transformer.h.6.attn.causal_mask', 'transformer.h.7.attn.causal_mask', 'transformer.h.8.attn.causal_mask', 'transformer.h.9.attn.causal_mask']
# ...

# %%
print(model)
print(tokenizer)
# Out:
# CodeGenForCausalLM(
#   (transformer): CodeGenModel(
#     (wte): Embedding(51200, 1024)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-19): 20 x CodeGenBlock(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc_out): Linear(in_features=4096, out_features=1024, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
# ...

# %%
tokenizer.pad_token = tokenizer.eos_token

# %%
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# 1

# %%
def tokenize_function(examples):
    return tokenizer(examples, truncation=True, padding=False)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# بارگذاری توکن‌آیزر و مدل
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-mono")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-mono")

# تنظیم pad_token به eos_token
tokenizer.pad_token = tokenizer.eos_token

# توکن‌سازی داده‌ها
def tokenize_function(examples):
    return tokenizer(examples["func_code_string"], truncation=True, padding="max_length", max_length=512)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# Some weights of the model checkpoint at Salesforce/codegen-350M-mono were not used when initializing CodeGenForCausalLM: ['transformer.h.0.attn.causal_mask', 'transformer.h.1.attn.causal_mask', 'transformer.h.10.attn.causal_mask', 'transformer.h.11.attn.causal_mask', 'transformer.h.12.attn.causal_mask', 'transformer.h.13.attn.causal_mask', 'transformer.h.14.attn.causal_mask', 'transformer.h.15.attn.causal_mask', 'transformer.h.16.attn.causal_mask', 'transformer.h.17.attn.causal_mask', 'transformer.h.18.attn.causal_mask', 'transformer.h.19.attn.causal_mask', 'transformer.h.2.attn.causal_mask', 'transformer.h.3.attn.causal_mask', 'transformer.h.4.attn.causal_mask', 'transformer.h.5.attn.causal_mask', 'transformer.h.6.attn.causal_mask', 'transformer.h.7.attn.causal_mask', 'transformer.h.8.attn.causal_mask', 'transformer.h.9.attn.causal_mask']
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# بارگذاری توکن‌آیزر و مدل
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-mono")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-mono")

# افزودن یک توکن پد جدید
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# توکن‌سازی داده‌ها
def tokenize_function(examples):
    return tokenizer(examples["func_code_string"], truncation=True, padding="max_length", max_length=512)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/999 [00:00<?, ?B/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# نصب کتابخانه‌های لازم
# !pip install transformers datasets

# بارگذاری دیتاست CodeSearchNet (زبان پایتون)
from datasets import load_dataset
dataset = load_dataset('code_search_net', 'python')

# بارگذاری توکن‌آیزر و مدل
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-mono")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-mono", ignore_mismatched_sizes=True)

# تنظیم pad_token به eos_token
tokenizer.pad_token = tokenizer.eos_token

# توکن‌سازی داده‌ها
def tokenize_function(examples):
    return tokenizer(examples["func_code_string"], truncation=True, padding="max_length", max_length=512)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.1 MB/s eta 0:00:00
# ...
# README.md:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# code_search_net.py:   0%|          | 0.00/8.44k [00:00<?, ?B/s]
# The repository for code_search_net contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/code_search_net.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] Y
# python.zip:   0%|          | 0.00/941M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/23107 [00:00<?, ? examples/s]
# ...

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=1,  # تعداد دوره‌های آموزش (برای تست می‌توانید این عدد را کم کنید)
    weight_decay=0.01,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=500,
    fp16=True,  # فعال‌سازی آموزش با دقت مختلط (برای GPU)
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],  # اگر داده‌های اعتبارسنجی دارید
)

# شروع آموزش
trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-52f02442e2d9> in <cell line: 0>()
#      24
#      25 # شروع آموزش
# ---> 26 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2169                 hf_hub_utils.enable_progress_bars()
#    2170         else:
# -> 2171             return inner_training_loop(
#    2172                 args=args,
#    2173                 resume_from_checkpoint=resume_from_checkpoint,
#
# ...

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=500,
    fp16=True,
    run_name="my_experiment_name",  # اضافه کردن run_name
)

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=500,
    fp16=True,
    report_to="none",  # غیرفعال کردن wandb
)

# %%
epoch = 1  # شماره دوره
loss = 0.5  # مقدار loss
accuracy = 0.9  # مقدار accuracy

# ذخیره نتایج در فایل
with open('/content/drive/MyDrive/experiment_results.txt', 'w') as f:
    f.write(f"Epoch: {epoch}, Loss: {loss}, Accuracy: {accuracy}")

# %%
from google.colab import drive

# اتصال Google Drive
drive.mount('/content/drive')

# تعریف متغیرها
epoch = 1  # شماره دوره
loss = 0.5  # مقدار loss
accuracy = 0.9  # مقدار accuracy

# ذخیره نتایج در فایل
with open('/content/drive/MyDrive/experiment_results.txt', 'w') as f:
    f.write(f"Epoch: {epoch}, Loss: {loss}, Accuracy: {accuracy}")

print("Results saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-552b0beceb0b> in <cell line: 0>()
#       2
#       3 # اتصال Google Drive
# ----> 4 drive.mount('/content/drive')
#       5
#       6 # تعریف متغیرها
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
# ...

# %%
from google.colab import drive

# اتصال Google Drive
drive.mount('/content/drive')

# ذخیره مدل
model.save_pretrained('/content/drive/MyDrive/my_model')

# ذخیره نتایج
with open('/content/drive/MyDrive/experiment_results.txt', 'w') as f:
    f.write(f"Epoch: {epoch}, Loss: {loss}, Accuracy: {accuracy}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-319f144c1e42> in <cell line: 0>()
#       9 # ذخیره نتایج
#      10 with open('/content/drive/MyDrive/experiment_results.txt', 'w') as f:
# ---> 11     f.write(f"Epoch: {epoch}, Loss: {loss}, Accuracy: {accuracy}")
#
# NameError: name 'epoch' is not defined

# %%
# ذخیره اطلاعات بیشتر در فایل
with open('/content/drive/MyDrive/additional_results.txt', 'w') as f:
    f.write("Additional information goes here.")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/* /content/drive/MyDrive/
# Out:
# cp: cannot stat '/content/drive/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.Encrypted/MyDrive/drive/.E
# ...

# %%
# !jupyter nbconvert --to html /content/your_notebook.ipynb
# Out:
# [NbConvertApp] WARNING | pattern '/content/your_notebook.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
# تبدیل نوت‌بوک به HTML
# !jupyter nbconvert --to html /content/my_notebook.ipynb

# کپی فایل HTML به Google Drive
# !cp /content/my_notebook.html /content/drive/MyDrive/
# Out:
# [NbConvertApp] WARNING | pattern '/content/my_notebook.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
# !ls /content/
# Out:
# drive  logs  results  sample_data

# %%
# مشاهده محتوای فایل JSON
# !cat /content/sample_data/anscombe.json

# مشاهده چند خط اول فایل CSV
# !head /content/sample_data/california_housing_train.csv
# Out:
# [
#   {"Series":"I", "X":10.0, "Y":8.04},
#   {"Series":"I", "X":8.0, "Y":6.95},
#   {"Series":"I", "X":13.0, "Y":7.58},
#   {"Series":"I", "X":9.0, "Y":8.81},
#   {"Series":"I", "X":11.0, "Y":8.33},
#   {"Series":"I", "X":14.0, "Y":9.96},
#   {"Series":"I", "X":6.0, "Y":7.24},
#   {"Series":"I", "X":4.0, "Y":4.26},
#   {"Series":"I", "X":12.0, "Y":10.84},
#   {"Series":"I", "X":7.0, "Y":4.81},
#   {"Series":"I", "X":5.0, "Y":5.68},
#
#   {"Series":"II", "X":10.0, "Y":9.14},
#   {"Series":"II", "X":8.0, "Y":8.14},
#   {"Series":"II", "X":13.0, "Y":8.74},
#   {"Series":"II", "X":9.0, "Y":8.77},
#   {"Series":"II", "X":11.0, "Y":9.26},
#   {"Series":"II", "X":14.0, "Y":8.10},
#   {"Series":"II", "X":6.0, "Y":6.13},
#   {"Series":"II", "X":4.0, "Y":3.10},
#   {"Series":"II", "X":12.0, "Y":9.13},
#   {"Series":"II", "X":7.0, "Y":7.26},
#   {"Series":"II", "X":5.0, "Y":4.74},
#
#   {"Series":"III", "X":10.0, "Y":7.46},
#   {"Series":"III", "X":8.0, "Y":6.77},
# ...

# %%
import pandas as pd

# بارگذاری داده‌های مسکن کالیفرنیا
california_housing_train = pd.read_csv('/content/sample_data/california_housing_train.csv')
print(california_housing_train.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# کپی فایل‌های مهم به Google Drive
# !cp -r /content/sample_data /content/drive/MyDrive/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# نصب TensorBoard
# !pip install tensorboard

# راه‌اندازی TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir /content/sample_data

# %%
# !cat /content/sample_data/README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
# ذخیره نوت‌بوک
from google.colab import files

# بررسی وجود فایل نوت‌بوک
# !ls /content/

# تغییر نام فایل نوت‌بوک (اختیاری)
# !mv /content/Untitled.ipynb /content/My-model-ai.ipynb

# دانلود فایل نوت‌بوک
files.download('My-model-ai.ipynb')
# Out:
# drive  logs  results  sample_data
# mv: cannot stat '/content/Untitled.ipynb': No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-ee709c1bf11e> in <cell line: 0>()
#       9
#      10 # دانلود فایل نوت‌بوک
# ---> 11 files.download('My-model-ai.ipynb')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: My-model-ai.ipynb

# %%
from google.colab import files

# ذخیره نوت‌بوک
# !jupyter nbconvert --to notebook --execute /content/My-model-ai.ipynb --output /content/My-model-ai-saved.ipynb

# دانلود فایل نوت‌بوک
files.download('/content/My-model-ai-saved.ipynb')
# Out:
# [NbConvertApp] WARNING | pattern '/content/My-model-ai.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %% [markdown]
# # New Section
